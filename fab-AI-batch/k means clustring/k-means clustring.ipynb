# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("students-record.csv")

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cgpa    200 non-null    float64
#  1   iq      200 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["cgpa"], data["iq"])
plt.xlabel("CGPA of Students")
plt.ylabel("IQ of Students")
plt.title("Students Record", color = "red")
# Out:
# Text(0.5, 1.0, 'Students Record')

# %%
# Elbow method.....

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

# %%
for i in range(1, 12):
    obj = KMeans(n_clusters = i)
    obj.fit_predict(data)
    wcss.append(obj.inertia_)

# %%
wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2503.397581,
#  681.96966,
#  582.7491892238326,
#  388.8524026875981,
#  310.7456081343755,
#  317.349838991674,
#  219.12270765932294,
#  188.4568369589887,
#  171.88039746114967]

# %%
plt.scatter(range(1, 12), wcss, label = "Elbow Points")
plt.plot(range(1, 12), wcss, color = "red", label = "Elbow Curve")
plt.xlabel("Number of Clusters")
plt.ylabel("Calculated WCSS ( Inertia)")
plt.title("Elbow Method")
plt.legend()
plt.grid()

# %%
mymodel = KMeans(n_clusters = 4)

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
x = data.iloc[:, :].values

# %%
x
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
mymodel.fit_predict(x)
# Out:
# array([2, 1, 0, 0, 1, 1, 0, 3, 1, 0, 2, 1, 0, 2, 1, 0, 1, 0, 1, 1, 0, 2,
#        0, 2, 2, 0, 2, 3, 0, 1, 3, 1, 3, 1, 0, 0, 3, 1, 2, 1, 2, 0, 0, 2,
#        3, 3, 0, 1, 3, 1, 2, 2, 3, 0, 3, 1, 1, 3, 1, 3, 1, 0, 0, 3, 2, 3,
#        0, 2, 1, 0, 1, 3, 0, 2, 1, 3, 1, 3, 2, 0, 0, 3, 1, 2, 3, 2, 3, 1,
#        3, 1, 3, 3, 0, 2, 0, 0, 3, 0, 2, 3, 1, 2, 2, 3, 2, 2, 0, 2, 3, 3,
#        0, 3, 1, 1, 0, 3, 0, 1, 3, 2, 2, 1, 0, 3, 0, 2, 0, 1, 2, 0, 0, 1,
#        2, 2, 1, 3, 1, 2, 0, 0, 0, 2, 1, 2, 2, 3, 2, 3, 1, 2, 3, 2, 3, 3,
#        2, 0, 1, 3, 1, 0, 2, 3, 1, 0, 3, 2, 1, 2, 2, 3, 3, 1, 3, 2, 2, 0,
#        3, 1, 2, 3, 3, 1, 1, 1, 0, 2, 0, 0, 3, 1, 0, 0, 2, 2, 0, 2, 3, 1,
#        1, 3])

# %%
data
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
students_clusters = mymodel.fit_predict(x)

# %%
students_clusters
# Out:
# array([3, 2, 1, 1, 2, 2, 1, 0, 2, 1, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 1, 3,
#        1, 3, 3, 1, 3, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3, 2, 3, 1, 1, 3,
#        0, 0, 1, 2, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 3, 0,
#        1, 3, 2, 1, 2, 0, 1, 3, 2, 0, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 2, 0, 0, 1, 3, 1, 1, 0, 1, 3, 0, 2, 3, 3, 0, 3, 3, 1, 3, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 3, 3, 2, 1, 0, 1, 3, 1, 2, 3, 1, 1, 2,
#        3, 3, 2, 0, 2, 3, 1, 1, 1, 3, 2, 3, 3, 0, 3, 0, 2, 3, 0, 3, 0, 0,
#        3, 1, 2, 0, 2, 1, 3, 0, 2, 1, 0, 3, 2, 3, 3, 0, 0, 2, 0, 3, 3, 1,
#        0, 2, 3, 0, 0, 2, 2, 2, 1, 3, 1, 1, 0, 2, 1, 1, 3, 3, 1, 3, 0, 2,
#        2, 0])

# %%
x
# Out:
# array([[  5.13,  88.  ],
#        [  5.9 , 113.  ],
#        [  8.36,  93.  ],
#        [  8.27,  97.  ],
#        [  5.45, 110.  ],
#        [  5.88, 109.  ],
#        [  8.41,  98.  ],
#        [  8.8 , 115.  ],
#        [  5.79, 110.  ],
#        [  8.09,  94.  ],
#        [  4.6 ,  86.  ],
#        [  6.1 , 110.  ],
#        [  8.16,  97.  ],
#        [  5.  ,  88.  ],
#        [  5.71, 108.  ],
#        [  8.31,  95.  ],
#        [  5.5 , 111.  ],
#        [  7.87,  91.  ],
#        [  6.05, 111.  ],
#        [  5.84, 113.  ],
#        [  7.47,  98.  ],
#        [  4.86,  86.  ],
#        [  7.78,  92.  ],
#        [  4.78,  87.  ],
#        [  4.96,  88.  ],
#        [  7.93,  98.  ],
#        [  4.86,  87.  ],
#        [  9.18, 119.  ],
#        [  8.04,  94.  ],
#        [  5.43, 106.  ],
#        [  8.86, 117.  ],
#        [  6.01, 112.  ],
#        [  8.83, 118.  ],
#        [  5.32, 106.  ],
#        [  7.77,  96.  ],
#        [  8.  ,  96.  ],
#        [  8.56, 118.  ],
# ...

# %%
x[students_clusters == 3]
# Out:
# array([[ 5.13, 88.  ],
#        [ 4.6 , 86.  ],
#        [ 5.  , 88.  ],
#        [ 4.86, 86.  ],
#        [ 4.78, 87.  ],
#        [ 4.96, 88.  ],
#        [ 4.86, 87.  ],
#        [ 5.44, 84.  ],
#        [ 5.34, 85.  ],
#        [ 5.31, 86.  ],
#        [ 5.14, 83.  ],
#        [ 4.95, 86.  ],
#        [ 5.21, 87.  ],
#        [ 4.91, 85.  ],
#        [ 5.28, 83.  ],
#        [ 5.15, 88.  ],
#        [ 4.9 , 85.  ],
#        [ 4.89, 88.  ],
#        [ 5.05, 86.  ],
#        [ 4.98, 91.  ],
#        [ 5.01, 86.  ],
#        [ 4.95, 88.  ],
#        [ 4.96, 89.  ],
#        [ 4.85, 86.  ],
#        [ 4.76, 90.  ],
#        [ 4.98, 87.  ],
#        [ 4.78, 87.  ],
#        [ 5.2 , 85.  ],
#        [ 5.05, 87.  ],
#        [ 5.01, 83.  ],
#        [ 4.77, 86.  ],
#        [ 4.68, 87.  ],
#        [ 4.81, 85.  ],
#        [ 5.03, 87.  ],
#        [ 4.98, 87.  ],
#        [ 5.32, 88.  ],
#        [ 4.86, 88.  ],
#        [ 4.89, 85.  ],
#        [ 4.88, 86.  ],
#        [ 5.01, 86.  ],
# ...

# %%
x[students_clusters == 3, 1]
# Out:
# array([88., 86., 88., 86., 87., 88., 87., 84., 85., 86., 83., 86., 87.,
#        85., 83., 88., 85., 88., 86., 91., 86., 88., 89., 86., 90., 87.,
#        87., 85., 87., 83., 86., 87., 85., 87., 87., 88., 88., 85., 86.,
#        86., 86., 85., 88., 88., 89., 88., 88., 89., 85., 89.])

# %%
plt.scatter(x[students_clusters == 0, 0], x[students_clusters == 0, 1], color = "red", label = "0th Cluster")
plt.scatter(x[students_clusters == 1, 0], x[students_clusters == 1, 1], color = "blue", label = "1th Cluster")
plt.scatter(x[students_clusters == 2, 0], x[students_clusters == 2, 1], color = "yellow", label = "2th Cluster")
plt.scatter(x[students_clusters == 3, 0], x[students_clusters == 3, 1], color = "green", label = "3th Cluster")
plt.legend()
plt.xlabel("CGPA of Students")
plt.ylabel("IQ of Students")
plt.title("Students Record", color = "red")
# Out:
# Text(0.5, 1.0, 'Students Record')
