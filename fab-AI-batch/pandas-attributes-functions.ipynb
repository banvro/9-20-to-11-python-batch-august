# %%
# Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data.shape
# Out:
# (816, 17)

# %%
data.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
data.tail(2)
# Out:
#           id       city        date player_of_match  \
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue           team1  \
# 814                 Sheikh Zayed Stadium              0  Delhi Capitals
# 815  Dubai International Cricket Stadium              0  Delhi Capitals
#
#                    team2     toss_winner toss_decision          winner  \
# 814  Sunrisers Hyderabad  Delhi Capitals           bat  Delhi Capitals
# 815       Mumbai Indians  Delhi Capitals           bat  Mumbai Indians
#
#       result  result_margin eliminator method      umpire1      umpire2
# 814     runs           17.0          N    NaN   PR Reiffel       S Ravi
# 815  wickets            5.0          N    NaN  CB Gaffaney  Nitin Menon

# %%
# sample()

# %%
data.sample(3)
# Out:
#          id       city        date player_of_match  \
# 160  419151     Nagpur  2010-04-12   Harmeet Singh
# 225  501249     Jaipur  2011-05-09         M Vijay
# 271  548329  Hyderabad  2012-05-10       DA Warner
#
#                                             venue  neutral_venue  \
# 160  Vidarbha Cricket Association Stadium, Jamtha              0
# 225                        Sawai Mansingh Stadium              0
# 271     Rajiv Gandhi International Stadium, Uppal              0
#
#                 team1                        team2  \
# 160   Deccan Chargers  Royal Challengers Bangalore
# 225  Rajasthan Royals          Chennai Super Kings
# 271   Deccan Chargers             Delhi Daredevils
#
#                      toss_winner toss_decision               winner   result  \
# 160  Royal Challengers Bangalore         field      Deccan Chargers     runs
# 225             Rajasthan Royals         field  Chennai Super Kings     runs
# ...

# %%
data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
# discrible()

# %%
data.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
data.head(2)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
# 1          Chennai Super Kings           bat    Chennai Super Kings   runs
#
#    result_margin eliminator method    umpire1      umpire2
# 0          140.0          N    NaN  Asad Rauf  RE Koertzen
# 1           33.0          N    NaN  MR Benson   SL Shastri

# %%
# data.values

# %%
# data.loc[0]

# %%
data["result"].values
# Out:
# array(['runs', 'runs', 'wickets', 'wickets', 'wickets', 'wickets',
#        'wickets', 'runs', 'wickets', 'runs', 'wickets', 'wickets',
#        'wickets', 'wickets', 'runs', 'wickets', 'runs', 'wickets', 'runs',
#        'wickets', 'wickets', 'runs', 'runs', 'wickets', 'wickets',
#        'wickets', 'wickets', 'wickets', 'runs', 'wickets', 'wickets',
#        'runs', 'runs', 'wickets', 'wickets', 'runs', 'wickets', 'runs',
#        'runs', 'wickets', 'runs', 'runs', 'runs', 'runs', 'wickets',
#        'wickets', 'runs', 'runs', 'wickets', 'wickets', 'runs', 'runs',
#        'wickets', 'wickets', 'wickets', 'runs', 'wickets', 'wickets',
#        'runs', 'runs', 'wickets', 'wickets', 'runs', 'runs', 'runs',
#        'runs', 'tie', 'wickets', 'runs', 'wickets', 'runs', 'wickets',
#        'runs', 'wickets', 'wickets', 'runs', 'wickets', 'runs', 'runs',
#        'runs', 'wickets', 'runs', 'wickets', 'wickets', 'runs', 'runs',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
data.isnull()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
data[data.isnull().any(axis=1)]
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data["method"].fillna("hellllloooo", inplace = True)

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
# pd.notnull

# %%
data = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data[data.notnull().any(axis=1)]
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data["method"] == None
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# Name: method, Length: 816, dtype: bool

# %%
data["method"].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'D/L', nan, nan, 'D/L', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, 'D/L', nan, nan,
#        'D/L', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'D/L', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
data.dropna
