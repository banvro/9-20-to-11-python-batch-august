# %%
# Matplotlib :

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
arr = np.array([12, 10, 89, 30, 40])
arr1 = np.array(["a", "b", "c", "d", "e"])

# %%
plt.bar(arr1, arr, width = 0.9 )
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(arr1, arr)
# Out:
# <BarContainer object of 5 artists>

# %%
arr1 = np.array([12, 1, 89, 10])

# %%
plt.pie(arr1)
# Out:
# ([<matplotlib.patches.Wedge at 0x22d07596290>,
# ...
#  [Text(1.038271662124374, 0.3633069716224698, ''),
#   Text(0.8404411077677323, 0.709689188570706, ''),
#   Text(-1.0961076402059735, -0.09245561682284353, ''),
#   Text(1.0570090752683927, -0.3045189892276962, '')])

# %%
arrx  =np.array([10, 40, 20, 30])

mylabsl = ["Orange", "apple", "grapes", "banana"]

# %%
plt.pie(arrx, labels = mylabsl)
# Out:
# ([<matplotlib.patches.Wedge at 0x22d078cbf90>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'Orange'),
#   Text(-0.3399187231970732, 1.046162158377023, 'apple'),
#   Text(-0.8899186574910393, -0.6465638275138399, 'grapes'),
#   Text(0.6465638691739385, -0.8899186272232008, 'banana')])

# %%
expolid = [0.1, 0, 0.2, 0]

# %%
plt.pie(arrx, labels = mylabsl, explode = expolid)
# Out:
# ([<matplotlib.patches.Wedge at 0x22d079505d0>,
# ...
#  [Text(1.1412678178182487, 0.3708203985925972, 'Orange'),
#   Text(-0.3399187231970732, 1.046162158377023, 'apple'),
#   Text(-1.0517220497621373, -0.7641208870618108, 'grapes'),
#   Text(0.6465638691739385, -0.8899186272232008, 'banana')])

# %%
import pandas as pd

# %%
data = pd.read_csv("placement.csv")

# %%
data
# Out:
#      cgpa package
# 0    6.89    3.26
# 1    5.12    1.98
# 2    7.82    3.25
# 3    7.42    3.67
# 4    6.94    3.57
# ..    ...     ...
# 195  6.93    2.46
# 196  5.89    2.57
# 197  7.21    3.24
# 198  7.63    3.96
# 199  6.22    2.33
#
# [200 rows x 2 columns]

# %%
x = data["cgpa"]
y = data["package"]

# %%
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
plt.scatter(y, x)
plt.xlabel("package")
plt.ylabel("cgpa")
plt.title("these ae students record")
# Out:
# Text(0.5, 1.0, 'these ae students record')
