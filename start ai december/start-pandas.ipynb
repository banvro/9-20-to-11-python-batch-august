# %%
Pandas : 
    1) Analizing
    2) Data Cleaning
    3) Exploration
    4) manupulatin data

# %%
2 types of data structure
    1) Series
    2) DataFrame

# %%
# !pip install pandas
# Out:
# ...
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/ae/d9/3741b344f57484b423cd22194025a8489992ad9962196a62721ef9980045/pandas-2.1.4-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy<2,>=1.26.0 from https://files.pythonhosted.org/packages/28/75/3b679b41713bb60e2e8f6e2f87be72c971c9e718b1c17b8f8749240ddca8/numpy-1.26.2-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.2 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 653.5 kB/s eta 0:00:00
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
lst = [12, 10, 90, 67, 10, 45, 34, 100]

# %%
tst = pd.Series(lst)

# %%
tst
# Out:
# 0     12
# 1     10
# 2     90
# 3     67
# 4     10
# 5     45
# 6     34
# 7    100
# dtype: int64

# %%
data = {
    "Username" : ["kriss", "moris", "hlo", "uname", "gni"],
    "Age" : [12, 34, 23, 12, 45],
    "Number" : [92342234, 45645345, 234234234, 456546445, 67876856756]
}

# %%
type(data)
# Out:
# dict

# %%
xyz = pd.DataFrame(data)

# %%
xyz
# Out:
#   Username  Age       Number
# 0    kriss   12     92342234
# 1    moris   34     45645345
# 2      hlo   23    234234234
# 3    uname   12    456546445
# 4      gni   45  67876856756

# %% [markdown]
# # index change

# %%
lst = [12, 10, 90, 67, 10, 45, 34, 100]

# %%
xyz = pd.Series(lst, index = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

# %%
xyz
# Out:
# a     12
# b     10
# c     90
# d     67
# e     10
# f     45
# g     34
# h    100
# dtype: int64

# %%
xyz
# Out:
#   Username  Age       Number
# 0    kriss   12     92342234
# 1    moris   34     45645345
# 2      hlo   23    234234234
# 3    uname   12    456546445
# 4      gni   45  67876856756

# %%
xyz.iloc[1]

# iloc
# Out:
# Username       moris
# Age               34
# Number      45645345
# Name: 1, dtype: object
